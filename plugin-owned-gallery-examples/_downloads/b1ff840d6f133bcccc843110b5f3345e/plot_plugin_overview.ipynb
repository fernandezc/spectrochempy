# %% [markdown]
# # Plugin-dependent examples.
#
# This section gathers examples that require optional SpectroChemPy
# plugins.
#
# Official plugins (`spectrochempy-iris`, `spectrochempy-nmr`,
# `spectrochempy-cantera`) also have dedicated examples in
# `Decomposition <examples-analysis-decomposition-index>`{.interpreted-text
# role="ref"},
# `Simulation <examples-analysis-simulation-index>`{.interpreted-text
# role="ref"}, and
# `NMR processing <examples-processing-nmr-index>`{.interpreted-text
# role="ref"}.
#
# See the `plugin-examples-list`{.interpreted-text role="ref"} page for
# the full list.
#
# Third-party plugin authors can add their own examples by placing a
# `plot_*.py` file in a subdirectory of this folder.

# %%
print("See the 'plugin-examples-list' page (linked above) for details.")
