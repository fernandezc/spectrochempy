# %% [markdown]
# # FTIR interferogram processing
#
# A situation where we need transform of real data is the case of FTIR interferogram.

# %%
import spectrochempy as scp
from spectrochempy.core.units import ur

# %%
ir = scp.read_spa("irdata/interferogram/interfero.SPA")
# Out:
# <style>/* SpectroChemPy output styling */
# .scp-output {
#     display: flex;
#     flex-direction: column;
#     gap: 2px;
# }
#
# .scp-output details {
#     padding: 1px;
# }
#
# .scp-output summary {
#     cursor: pointer;
#     font-weight: normal;
#     /*bold;*/
#     font-size: 11pt;
# }
#
# .scp-output summary:hover {
#     color: #888;
# }
#
# /* Parameters display styling */
# .scp-output .section {
#     display: flex;
#     flex-direction: row;
#     gap: 2px;
#     font-family: Arial, sans-serif;
#     font-size: 10pt;
#     margin-left: 15px;
# }
#
# .scp-output .meta-name,
# .scp-output .attr-name {
#     font-weight: 500;
#     color: #28A745;
#     text-align: right;
# }
#
# .scp-output .attr-name {
#     min-width: 100px;
# }
#
# .scp-output .meta-name {
#     min-width: 150px;
# }
#
# .scp-output .meta-value,
# .scp-output .attr-value {
#     flex: 1;
# }
#
# .scp-output .numeric {
#     color: #2D7FF9;
#     margin-left: 120px;
#     font-size: 10pt;
# }
#
# .scp-output .label {
#     color: darkcyan;
#     margin-left: 120px;
#     font-size: 10pt;
# }
#
# .scp-output .attr-value .numeric {
#     color: #2D7FF9;
#     margin-left: 0px;
#     font-size: 10pt;
# }
#
# .scp-output .attr-value .label {
#     color: darkcyan;
#     margin-left: 0px;
#     font-size: 10pt;
# }
# </style>

# %% [markdown]
# By default, the interferogram is displayed with an axis in points (no units).

# %%
prefs = scp.preferences
prefs.figure.figsize = (7, 3)
_ = ir.plot()
print("number of points = ", ir.size)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scpy'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 3
#       1 prefs = scp.preferences
#       2 prefs.figure.figsize = (7, 3)
# ----> 3 _ = ir.plot()
#       4 print("number of points = ", ir.size)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/dataset/nddataset.py:1733, in NDDataset.plot(self, method, **kwargs)
#    1675 """
#    1676 Plot the dataset.
#    1677
#    (...)   1729 plotting.plot3d : 3D plotting functions.
#    1730 """
#    1731 from spectrochempy.plotting.dispatcher import plot_dataset
# -> 1733 return plot_dataset(self, method=method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/dispatcher.py:65, in plot_dataset(dataset, method, backend, **kwargs)
#      62 import importlib
#      64 backend_module = importlib.import_module(module_path)
# ---> 65 return backend_module.plot_dataset_impl(dataset, method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/backends/matplotlib_backend.py:159, in plot_dataset_impl(dataset, method, **kwargs)
#     156 show = kwargs.pop("show", True)
#     158 # Call the standalone plot function with dataset as first argument
# --> 159 ax = plot_func(dataset, **kwargs)
#     161 # Show the figure if requested
#     162 if show:
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:754, in plot_pen(dataset, **kwargs)
#     645 def plot_pen(dataset, **kwargs):
#     646     """
#     647     Plot a 1D dataset with solid pen by default.
#     648
#    (...)    752     multiplot
#     753     """
# --> 754     return plot_1D(dataset, method="pen", **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:186, in plot_1D(dataset, method, **kwargs)
#     183 merged_overrides.update(font_overrides)
#     185 # Apply styles and font overrides within context for entire plotting operation
# --> 186 with plt.style.context(style), matplotlib.rc_context(merged_overrides):
#     187     # Redirections ?
#     188     # ------------------------------------------------------------------------
#     189     # should we redirect the plotting to another method
#     190     if dataset._squeeze_ndim > 1:
#     191         return dataset.plot_2D(**kwargs)
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:186, in context(style, after_reset)
#     184 if after_reset:
#     185     mpl.rcdefaults()
# --> 186 use(style)
#     187 yield
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'scpy' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %% [markdown]
# Plotting a zoomed region around the maximum of the interferogram
# (the so-called `ZPD`: `Zero optical Path Difference` ) we can see that it is located
# around the 64th points. The FFT processing will need this information,
# but it will be determined automatically.

# %%
_ = ir.plot(xlim=(0, 128))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scpy'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 _ = ir.plot(xlim=(0, 128))
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/dataset/nddataset.py:1733, in NDDataset.plot(self, method, **kwargs)
#    1675 """
#    1676 Plot the dataset.
#    1677
#    (...)   1729 plotting.plot3d : 3D plotting functions.
#    1730 """
#    1731 from spectrochempy.plotting.dispatcher import plot_dataset
# -> 1733 return plot_dataset(self, method=method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/dispatcher.py:65, in plot_dataset(dataset, method, backend, **kwargs)
#      62 import importlib
#      64 backend_module = importlib.import_module(module_path)
# ---> 65 return backend_module.plot_dataset_impl(dataset, method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/backends/matplotlib_backend.py:159, in plot_dataset_impl(dataset, method, **kwargs)
#     156 show = kwargs.pop("show", True)
#     158 # Call the standalone plot function with dataset as first argument
# --> 159 ax = plot_func(dataset, **kwargs)
#     161 # Show the figure if requested
#     162 if show:
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:754, in plot_pen(dataset, **kwargs)
#     645 def plot_pen(dataset, **kwargs):
#     646     """
#     647     Plot a 1D dataset with solid pen by default.
#     648
#    (...)    752     multiplot
#     753     """
# --> 754     return plot_1D(dataset, method="pen", **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:186, in plot_1D(dataset, method, **kwargs)
#     183 merged_overrides.update(font_overrides)
#     185 # Apply styles and font overrides within context for entire plotting operation
# --> 186 with plt.style.context(style), matplotlib.rc_context(merged_overrides):
#     187     # Redirections ?
#     188     # ------------------------------------------------------------------------
#     189     # should we redirect the plotting to another method
#     190     if dataset._squeeze_ndim > 1:
#     191         return dataset.plot_2D(**kwargs)
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:186, in context(style, after_reset)
#     184 if after_reset:
#     185     mpl.rcdefaults()
# --> 186 use(style)
#     187 yield
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'scpy' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %% [markdown]
# The `x` scale of the interferogram can also be displayed as a function of optical
# path difference. For this we just make `show_datapoints` to False:

# %%
ir.x.show_datapoints = False
_ = ir.plot(xlim=(-0.04, 0.04))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scpy'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 2
#       1 ir.x.show_datapoints = False
# ----> 2 _ = ir.plot(xlim=(-0.04, 0.04))
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/dataset/nddataset.py:1733, in NDDataset.plot(self, method, **kwargs)
#    1675 """
#    1676 Plot the dataset.
#    1677
#    (...)   1729 plotting.plot3d : 3D plotting functions.
#    1730 """
#    1731 from spectrochempy.plotting.dispatcher import plot_dataset
# -> 1733 return plot_dataset(self, method=method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/dispatcher.py:65, in plot_dataset(dataset, method, backend, **kwargs)
#      62 import importlib
#      64 backend_module = importlib.import_module(module_path)
# ---> 65 return backend_module.plot_dataset_impl(dataset, method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/backends/matplotlib_backend.py:159, in plot_dataset_impl(dataset, method, **kwargs)
#     156 show = kwargs.pop("show", True)
#     158 # Call the standalone plot function with dataset as first argument
# --> 159 ax = plot_func(dataset, **kwargs)
#     161 # Show the figure if requested
#     162 if show:
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:754, in plot_pen(dataset, **kwargs)
#     645 def plot_pen(dataset, **kwargs):
#     646     """
#     647     Plot a 1D dataset with solid pen by default.
#     648
#    (...)    752     multiplot
#     753     """
# --> 754     return plot_1D(dataset, method="pen", **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:186, in plot_1D(dataset, method, **kwargs)
#     183 merged_overrides.update(font_overrides)
#     185 # Apply styles and font overrides within context for entire plotting operation
# --> 186 with plt.style.context(style), matplotlib.rc_context(merged_overrides):
#     187     # Redirections ?
#     188     # ------------------------------------------------------------------------
#     189     # should we redirect the plotting to another method
#     190     if dataset._squeeze_ndim > 1:
#     191         return dataset.plot_2D(**kwargs)
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:186, in context(style, after_reset)
#     184 if after_reset:
#     185     mpl.rcdefaults()
# --> 186 use(style)
#     187 yield
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'scpy' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %% [markdown]
# Note that the `x` scale of the interferogram has been calculated using the laser
# frequency indicated in the original omnic file. It is stored in the `meta` attribute
# of the NDDataset:

# %%
print(ir.meta.laser_frequency)
# Out:
# 15798.259765625 cm⁻¹

# %% [markdown]
# If absent, it can be set using the `set_laser_frequency()` method, e.g.:

# %%
ir.x.set_laser_frequency(15798.26 * ur("cm^-1"))

# %% [markdown]
# Now we can perform the Fourier transform. By default, no zero-filling level is applied
# prior the Fourier transform for FTIR. To add some level of zero-filling,
# use the `zf` method.

# %%
ird = ir.dc()
ird = ird.zf(size=2 * ird.size)
irt = ird.fft()

_ = irt.plot(xlim=(3999, 400))
# Out:
#  WARNING | (RuntimeWarning) divide by zero encountered in divide
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scpy'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 5
#       1 ird = ir.dc()
#       2 ird = ird.zf(size=2 * ird.size)
#       3 irt = ird.fft()
#       4
# ----> 5 _ = irt.plot(xlim=(3999, 400))
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/dataset/nddataset.py:1733, in NDDataset.plot(self, method, **kwargs)
#    1675 """
#    1676 Plot the dataset.
#    1677
#    (...)   1729 plotting.plot3d : 3D plotting functions.
#    1730 """
#    1731 from spectrochempy.plotting.dispatcher import plot_dataset
# -> 1733 return plot_dataset(self, method=method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/dispatcher.py:65, in plot_dataset(dataset, method, backend, **kwargs)
#      62 import importlib
#      64 backend_module = importlib.import_module(module_path)
# ---> 65 return backend_module.plot_dataset_impl(dataset, method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/backends/matplotlib_backend.py:159, in plot_dataset_impl(dataset, method, **kwargs)
#     156 show = kwargs.pop("show", True)
#     158 # Call the standalone plot function with dataset as first argument
# --> 159 ax = plot_func(dataset, **kwargs)
#     161 # Show the figure if requested
#     162 if show:
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:754, in plot_pen(dataset, **kwargs)
#     645 def plot_pen(dataset, **kwargs):
#     646     """
#     647     Plot a 1D dataset with solid pen by default.
#     648
#    (...)    752     multiplot
#     753     """
# --> 754     return plot_1D(dataset, method="pen", **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:186, in plot_1D(dataset, method, **kwargs)
#     183 merged_overrides.update(font_overrides)
#     185 # Apply styles and font overrides within context for entire plotting operation
# --> 186 with plt.style.context(style), matplotlib.rc_context(merged_overrides):
#     187     # Redirections ?
#     188     # ------------------------------------------------------------------------
#     189     # should we redirect the plotting to another method
#     190     if dataset._squeeze_ndim > 1:
#     191         return dataset.plot_2D(**kwargs)
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:186, in context(style, after_reset)
#     184 if after_reset:
#     185     mpl.rcdefaults()
# --> 186 use(style)
#     187 yield
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'scpy' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %% [markdown]
# A `Happ-Genzel` (Hamming window) apodization can also be applied prior to the
# Fourier transformation in order to decrease the H2O narrow bands.

# %%
ird = ir.dc()
irdh = ird.hamming()
irdh.zf(inplace=True, size=2 * ird.size)
irth = irdh.fft()
_ = irth.plot(xlim=(3999, 400))
# Out:
#  WARNING | (RuntimeWarning) divide by zero encountered in divide
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scpy'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 5
#       1 ird = ir.dc()
#       2 irdh = ird.hamming()
#       3 irdh.zf(inplace=True, size=2 * ird.size)
#       4 irth = irdh.fft()
# ----> 5 _ = irth.plot(xlim=(3999, 400))
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/dataset/nddataset.py:1733, in NDDataset.plot(self, method, **kwargs)
#    1675 """
#    1676 Plot the dataset.
#    1677
#    (...)   1729 plotting.plot3d : 3D plotting functions.
#    1730 """
#    1731 from spectrochempy.plotting.dispatcher import plot_dataset
# -> 1733 return plot_dataset(self, method=method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/dispatcher.py:65, in plot_dataset(dataset, method, backend, **kwargs)
#      62 import importlib
#      64 backend_module = importlib.import_module(module_path)
# ---> 65 return backend_module.plot_dataset_impl(dataset, method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/backends/matplotlib_backend.py:159, in plot_dataset_impl(dataset, method, **kwargs)
#     156 show = kwargs.pop("show", True)
#     158 # Call the standalone plot function with dataset as first argument
# --> 159 ax = plot_func(dataset, **kwargs)
#     161 # Show the figure if requested
#     162 if show:
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:754, in plot_pen(dataset, **kwargs)
#     645 def plot_pen(dataset, **kwargs):
#     646     """
#     647     Plot a 1D dataset with solid pen by default.
#     648
#    (...)    752     multiplot
#     753     """
# --> 754     return plot_1D(dataset, method="pen", **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:186, in plot_1D(dataset, method, **kwargs)
#     183 merged_overrides.update(font_overrides)
#     185 # Apply styles and font overrides within context for entire plotting operation
# --> 186 with plt.style.context(style), matplotlib.rc_context(merged_overrides):
#     187     # Redirections ?
#     188     # ------------------------------------------------------------------------
#     189     # should we redirect the plotting to another method
#     190     if dataset._squeeze_ndim > 1:
#     191         return dataset.plot_2D(**kwargs)
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:186, in context(style, after_reset)
#     184 if after_reset:
#     185     mpl.rcdefaults()
# --> 186 use(style)
#     187 yield
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'scpy' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %% [markdown]
# ## Comparison with the OMNIC processing.
#
# Here we compare the OMNIC processed spectra of the same interferogram and ours in red.
# One can see that the results are very close

# %%
irs = scp.read_spa("irdata/interferogram/spectre.SPA")
prefs.figure.figsize = (7, 6)
ax = irs.plot(label="omnic")
_ = (irt + 0.4).plot(c="red", linestyle="solid", clear=False, label="no hamming")
_ = (irth + 0.2).plot(c="green", linestyle="solid", clear=False, label="hamming")
ax.set_xlim(4000.0, 400.0)
ax.set_ylim(0.0, 3.1)
_ = ax.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scpy'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 3
#       1 irs = scp.read_spa("irdata/interferogram/spectre.SPA")
#       2 prefs.figure.figsize = (7, 6)
# ----> 3 ax = irs.plot(label="omnic")
#       4 _ = (irt + 0.4).plot(c="red", linestyle="solid", clear=False, label="no hamming")
#       5 _ = (irth + 0.2).plot(c="green", linestyle="solid", clear=False, label="hamming")
#       6 ax.set_xlim(4000.0, 400.0)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/dataset/nddataset.py:1733, in NDDataset.plot(self, method, **kwargs)
#    1675 """
#    1676 Plot the dataset.
#    1677
#    (...)   1729 plotting.plot3d : 3D plotting functions.
#    1730 """
#    1731 from spectrochempy.plotting.dispatcher import plot_dataset
# -> 1733 return plot_dataset(self, method=method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/dispatcher.py:65, in plot_dataset(dataset, method, backend, **kwargs)
#      62 import importlib
#      64 backend_module = importlib.import_module(module_path)
# ---> 65 return backend_module.plot_dataset_impl(dataset, method, **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/backends/matplotlib_backend.py:159, in plot_dataset_impl(dataset, method, **kwargs)
#     156 show = kwargs.pop("show", True)
#     158 # Call the standalone plot function with dataset as first argument
# --> 159 ax = plot_func(dataset, **kwargs)
#     161 # Show the figure if requested
#     162 if show:
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:754, in plot_pen(dataset, **kwargs)
#     645 def plot_pen(dataset, **kwargs):
#     646     """
#     647     Plot a 1D dataset with solid pen by default.
#     648
#    (...)    752     multiplot
#     753     """
# --> 754     return plot_1D(dataset, method="pen", **kwargs)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/plotting/plot1d.py:186, in plot_1D(dataset, method, **kwargs)
#     183 merged_overrides.update(font_overrides)
#     185 # Apply styles and font overrides within context for entire plotting operation
# --> 186 with plt.style.context(style), matplotlib.rc_context(merged_overrides):
#     187     # Redirections ?
#     188     # ------------------------------------------------------------------------
#     189     # should we redirect the plotting to another method
#     190     if dataset._squeeze_ndim > 1:
#     191         return dataset.plot_2D(**kwargs)
#
# File /opt/hostedtoolcache/Python/3.13.13/x64/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:186, in context(style, after_reset)
#     184 if after_reset:
#     185     mpl.rcdefaults()
# --> 186 use(style)
#     187 yield
#
# File ~/work/spectrochempy/spectrochempy/.venv/lib/python3.13/site-packages/matplotlib/style/core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'scpy' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)
